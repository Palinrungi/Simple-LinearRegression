# %% [markdown]
# # **Model Simple LinearRegression (Memprediksi berapa jarak yang dapat ditempuh berdasarkan berapa jumlah bensin)**

# %% [markdown]
# ## Melakukan import semua library yang dibutuhkan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.model_selection as ms
import sklearn.linear_model as lm

# %% [markdown]
# ## Menyiapkan Data

# %%
df1 = pd.read_csv('ML DATA/bensin.csv')
df1
# Out:
#     Liter  Kilometer
# 0      20      142.0
# 1      25      177.0
# 2      20      144.0
# 3      30      203.0
# 4      40      273.0
# ..    ...        ...
# 60     31      203.0
# 61     37      241.0
# 62     23      142.0
# 63     36      241.0
# 64     23      142.0
#
# [65 rows x 2 columns]

# %%
df1.tail(10)
# Out:
#     Liter  Kilometer
# 55     32      239.0
# 56     31      221.0
# 57     41      255.0
# 58     27      181.0
# 59     30      214.0
# 60     31      203.0
# 61     37      241.0
# 62     23      142.0
# 63     36      241.0
# 64     23      142.0

# %%
df1.describe()
# Out:
#            Liter   Kilometer
# count  65.000000   65.000000
# mean   26.446154  181.064615
# std     7.424686   49.741763
# min     6.000000   32.000000
# 25%    23.000000  144.000000
# 50%    25.000000  177.000000
# 75%    30.000000  212.000000
# max    45.000000  278.000000

# %% [markdown]
# ## Memisahkan Data Train dan Test

# %% [markdown]
# memisahkan data training dan test dengan ukuran 0.2 / 80 20

# %%
liter = df1[['Liter']]
kilometer = df1[['Kilometer']]
X_train, X_test, y_train, y_test = ms.train_test_split(liter, kilometer, test_size=0.2, random_state=0)
print (X_train.size, X_test.size)
# Out:
# 52 13

# %% [markdown]
# ## Visualisasi

# %%
plt.scatter(X_train, y_train, edgecolors='r')
plt.xlabel('liter')
plt.ylabel('kilometer')
plt.title('Konsumsi Bahan Bakar')
plt.show()

# %% [markdown]
# ## Menambahkan Regression Line

# %%
plt.scatter(X_train, y_train, edgecolors='r')
plt.xlabel('liter')
plt.ylabel('kilometer')
plt.title('Konsumsi Bahan Bakar')
x1 = np.linspace(0,45)
y1 = 4 + 7 * x1
plt.plot(x1,y1)
plt.show()

# %% [markdown]
# ## Melatih Model

# %% [markdown]
# Latih Model Dengan Metode OLS

# %%
model1=lm.LinearRegression()
model1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Melihat Nilai Slope

# %%
model1.coef_
# Out:
# array([[6.45829591]])

# %% [markdown]
# Melihat Nilai Intercept

# %%
model1.intercept_
# Out:
# array([10.64122249])

# %% [markdown]
# Visualkan dengn diagram garis dengan memasukkan angka slope dan intercept untuk formula variabel y1

# %%
plt.scatter(X_train, y_train, edgecolors='r')
plt.xlabel('liter')
plt.ylabel('kilometer')
plt.title('Konsumsi Bahan Bakar')
x1 = np.linspace(0,45)
y1 = 10.64 + 6.45 * x1
plt.plot(x1,y1)
plt.show()

# %% [markdown]
# ## Scoring Model

# %% [markdown]
# Scoring menggunakan R-Square

# %%
r2 = model1.score(X_test, y_test)
print (r2)
# Out:
# 0.9798523775622333

# %% [markdown]
# Melakukan Prediksi
# Ternyata dengan 60 liter bensin dapat menempuh jarak sejauh 398.13 km

# %%
jarak = model1.predict([[60]])
print (jarak)
# Out:
# [[398.13897723]]
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Melakukan prediksi dari semua isi dataset

# %%
prediksi = model1.predict(X_test)
print (prediksi)
# Out:
# [[107.51566118]
#  [172.0986203 ]
#  [172.0986203 ]
#  [159.18202848]
#  [139.80714074]
#  [268.97305898]
#  [204.39009986]
#  [236.68157942]
#  [ 75.22418162]
#  [243.13987534]
#  [172.0986203 ]
#  [139.80714074]
#  [191.47350804]]

# %% [markdown]
# Melihat angka kilometer dari variabel y_test untuk dibandingkan dengan hasil prediksi

# %%
print (y_test)
# Out:
#     Kilometer
# 45      102.0
# 29      167.0
# 43      177.0
# 62      142.0
# 34      144.0
# 33      278.0
# 31      211.0
# 40      241.0
# 26       65.0
# 63      241.0
# 22      166.2
# 2       144.0
# 11      180.0
